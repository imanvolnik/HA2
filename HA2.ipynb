# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **1- Which type of data can be used while creating a series object in pandas?**
#
# Pandas Series is a one-dimensional array of data. It can hold any type of data: string, integer, float, dictionaries, lists, booleans, and more.

# %% [markdown]
# **2- Create a series having the month's number as data and assign name as their index values?**

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
ser = pd.Series(np.arange(1, 13), index = months)
ser
# Out:
# January       1
# February      2
# March         3
# April         4
# May           5
# June          6
# July          7
# August        8
# September     9
# October      10
# November     11
# December     12
# dtype: int64

# %% [markdown]
# **3-Write a program to create a series object using the dictionary which store the number of students in fresh batch groups ( MatMIE, Mat DAIS, COMIE, COMEC)?**

# %%
freshmen = {
    "MATMIE23": 29,
    "MATDAIS23": 30,
    "COMIE23": 27,
    "COMEC": 32
}

freshmen_sr = pd.Series(freshmen)
freshmen_sr
# Out:
# MATMIE23     29
# MATDAIS23    30
# COMIE23      27
# COMEC        32
# dtype: int64

# %% [markdown]
# **4-  Write a Pandas program to create and display a DataFrame from a specified dictionary data which has the index labels.
# Sample Python dictionary data and list labels:**
#
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
#
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
exam_data = {
    'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
    }
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(exam_data, index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# **5- Write a Pandas program to select the rows where the number of attempts in the examination is greater than 2.**
# **Sample Python dictionary data and list labels:**
#
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
#
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df[df["attempts"] > 2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes
